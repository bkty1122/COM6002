# %% [markdown]
# # KGOT algothrim snapshot

# %% [markdown]
# ## Code improved

# %% [markdown]
# ### KGOT algorithm

# %% [markdown]
# #### Straightening

# %%
import json
import numpy as np
import cv2
from pycocotools import mask as mask_utils
from scipy.interpolate import interp1d
import os
from skimage.draw import line
import time


def interpolate_centerline(keypoints, num_points):
    t = np.linspace(0, 1, len(keypoints))
    t_new = np.linspace(0, 1, num_points)
    fx = interp1d(t, keypoints[:, 0], kind='cubic', bounds_error=False, fill_value="extrapolate")
    fy = interp1d(t, keypoints[:, 1], kind='cubic', bounds_error=False, fill_value="extrapolate")
    return np.column_stack((fx(t_new), fy(t_new)))

def calculate_tangents_and_normals(points):
    tangents = np.gradient(points, axis=0)
    tangents = tangents / np.linalg.norm(tangents, axis=1)[:, np.newaxis]
    normals = np.column_stack((-tangents[:, 1], tangents[:, 0]))
    return tangents, normals

def prepare_centerline(centerline, num_segments):
    centerline_interp = interpolate_centerline(centerline, num_segments * 10)
    _, normals = calculate_tangents_and_normals(centerline_interp)
    indices = np.linspace(0, len(centerline_interp) - 1, num_segments + 1, dtype=int)
    selected_points = centerline_interp[indices]
    return centerline_interp, normals, indices, selected_points

def calculate_width_and_fill_mask(mask, point, normal, segment_mask=None):
    width = 0
    for direction in [1, -1]:
        current_point = np.array(point, dtype=float)
        while True:
            x, y = np.round(current_point).astype(int)
            if x < 0 or x >= mask.shape[1] or y < 0 or y >= mask.shape[0] or mask[y, x] == 0:
                break
            if segment_mask is not None:
                segment_mask[y, x] = 255
            current_point += direction * normal
            width += 1
    return width

def process_segment(mask, start_point, end_point, normal, create_mask=False):
    segment_mask = np.zeros_like(mask, dtype=np.uint8) if create_mask else None
    segment_widths = []
    rr, cc = line(int(start_point[1]), int(start_point[0]), int(end_point[1]), int(end_point[0]))
    
    for r, c in zip(rr, cc):
        width = calculate_width_and_fill_mask(mask, (c, r), normal, segment_mask)
        segment_widths.append(width)
    
    return segment_mask, np.mean(segment_widths)

def process_centerline(mask, centerline, num_segments, create_masks=False):
    centerline_interp, normals, indices, selected_points = prepare_centerline(np.array(centerline), num_segments)

    segment_masks = []
    widths = []

    for i in range(len(selected_points) - 1):
        start_point = selected_points[i]
        end_point = selected_points[i + 1]
        normal = normals[indices[i]]
        
        segment_mask, width = process_segment(mask, start_point, end_point, normal, create_masks)
        
        if create_masks:
            segment_masks.append(segment_mask)
        widths.append(width)

    return segment_masks, widths

def divide_mask_by_centerline(mask, centerline, num_segments=10):
    segment_masks, widths = process_centerline(mask, centerline, num_segments, create_masks=True)
    return segment_masks, widths

def calculate_average_width(mask, centerline, num_segments=10):
    _, widths = process_centerline(mask, centerline, num_segments, create_masks=False)
    return np.mean(widths)

def ensure_rgba(image):
    if image.shape[2] == 3:
        return cv2.cvtColor(image, cv2.COLOR_BGR2RGBA)
    elif image.shape[2] == 4:
        return cv2.cvtColor(image, cv2.COLOR_BGRA2RGBA)
    return image

def straighten_image(image, keypoints, mask, output_length, output_width):
    h, w = image.shape[:2]
    output_height = int(output_width * (h / w))
    straightened = np.zeros((output_height, int(output_length), 4), dtype=np.uint8)

    # Ensure image is in RGBA format
    image = ensure_rgba(image)
    
    centerline = interpolate_centerline(keypoints, int(output_length))
    _, normals = calculate_tangents_and_normals(centerline)

    for i in range(int(output_length)):
        cx, cy = centerline[i]
        nx, ny = normals[i]

        for j in range(output_height):
            offset = (j - output_height / 2)
            sx, sy = int(cx + offset * nx), int(cy + offset * ny)

            if 0 <= sx < w and 0 <= sy < h and mask[sy, sx]:
                straightened[j, i] = image[sy, sx]
            else:
                straightened[j, i] = [0, 0, 0, 0]

    return straightened

def load_and_preprocess_image(image_path):
    # Read image in BGR format
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    # Convert to RGBA
    return ensure_rgba(image)

def save_straightened_image(image, output_path):
    cv2.imwrite(output_path, image, [cv2.IMWRITE_PNG_COMPRESSION, 9])

# %%
import numpy as np
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter1d
import cv2

def generate_reference_curve(keypoints, num_points=1000, target_length=None):
    distances = np.linalg.norm(np.diff(keypoints, axis=0), axis=1)
    original_total_length = np.sum(distances)
    
    print(f"Original length: {original_total_length:.2f}")
    print(f"Target length: {target_length}")
    
    if target_length is not None:
        scale_factor = target_length / original_total_length
        scaled_distances = distances * scale_factor
        scaled_cumulative_distances = np.insert(np.cumsum(scaled_distances), 0, 0)
        
        scaled_keypoints = np.zeros_like(keypoints)
        scaled_keypoints[0] = keypoints[0]
        scaled_keypoints[1:] = keypoints[0] + np.cumsum(np.diff(keypoints, axis=0) * scale_factor, axis=0)
        
        t = np.linspace(0, 1, num_points)
        f = interp1d(scaled_cumulative_distances / scaled_cumulative_distances[-1], scaled_keypoints, axis=0, kind='linear')
        smooth_curve = f(t)
        
        sigma = 1 * scale_factor
        smooth_curve = gaussian_filter1d(smooth_curve, sigma, axis=0)
    else:
        scale_factor = 1
        smooth_curve = keypoints
    
    new_length = np.sum(np.linalg.norm(np.diff(smooth_curve, axis=0), axis=1))
    print(f"New length: {new_length:.2f}")
    print(f"Scale factor: {scale_factor:.2f}")
    
    return smooth_curve, scale_factor

def warp_straightened_image(straightened, reference_curve, avg_width, scale_factor=None):
    height, width = straightened.shape[:2]
    
    extended_curve = interpolate_centerline(reference_curve, int(len(reference_curve) * 1.2))
    
    min_x, min_y = np.min(extended_curve, axis=0)
    max_x, max_y = np.max(extended_curve, axis=0)
    
    padding = avg_width
    output_width = int(max_x - min_x + 2 * padding)
    output_height = int(max_y - min_y + 2 * padding)
    
    warped = np.zeros((output_height, output_width, 4), dtype=np.uint8)
    weight = np.zeros((output_height, output_width), dtype=np.float32)
    
    _, normals = calculate_tangents_and_normals(extended_curve)
    
    straightened = ensure_rgba(straightened)
    
    y_coords, x_coords = np.mgrid[0:height, 0:width]
    t = x_coords / width
    curve_indices = np.minimum((t * (len(extended_curve) - 1)).astype(int), len(extended_curve) - 1)
    
    curve_points = extended_curve[curve_indices]
    normal_vectors = normals[curve_indices]
    
    offsets = (y_coords / height - 0.5) * avg_width
    
    warped_coords = curve_points - [min_x, min_y] + [padding, padding] + offsets[:, :, np.newaxis] * normal_vectors
    warped_coords = warped_coords.astype(int)
    
    valid_mask = (warped_coords[:, :, 0] >= 0) & (warped_coords[:, :, 0] < output_width) & \
                 (warped_coords[:, :, 1] >= 0) & (warped_coords[:, :, 1] < output_height)
    
    warped[warped_coords[valid_mask, 1], warped_coords[valid_mask, 0]] = straightened[y_coords[valid_mask], x_coords[valid_mask]]
    weight[warped_coords[valid_mask, 1], warped_coords[valid_mask, 0]] += 1

    mask = (warped[:,:,3] > 0).astype(np.uint8) * 255

    kernel_close = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    closed_mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel_close)

    contours, _ = cv2.findContours(closed_mask, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

    fill_mask = np.zeros_like(mask)
    cv2.drawContours(fill_mask, contours, -1, 255, -1)

    # kernel_dilate = np.ones((3, 3), np.uint8)
    # fill_mask_dilated = cv2.dilate(fill_mask, kernel_dilate, iterations=2)

    # transparent_mask = (fill_mask_dilated == 255) & (warped[:,:,3] == 0)
    transparent_mask = (fill_mask == 255) & (warped[:,:,3] == 0)

    warped_filled = warped.copy()
    for i in range(3):
        warped_filled[:,:,i] = cv2.inpaint(warped[:,:,i], transparent_mask.astype(np.uint8), 3, cv2.INPAINT_TELEA)
    
    warped_filled[:,:,3] = np.where(transparent_mask, 255, warped[:,:,3])

    # edge = cv2.Canny(fill_mask_dilated, 100, 200)
    
    # Ensure output is in RGBA format
    warped = cv2.cvtColor(warped, cv2.COLOR_BGRA2RGBA)
    warped_filled = cv2.cvtColor(warped_filled, cv2.COLOR_BGRA2RGBA)

    return warped, warped_filled, warped

# %% [markdown]
# ## Image processing code

# %%
def circulate_image_from_coco(json_file_path, image_folder, output_folder, output_width=1024, output_height=1024, scale=True):
    with open(json_file_path, 'r') as f:
        coco_data = json.load(f)

    os.makedirs(output_folder, exist_ok=True)

    image_ids = set(ann['image_id'] for ann in coco_data['annotations'])

    frame_images = []

    for ref_image_id in image_ids:
        ref_ann = next((ann for ann in coco_data['annotations'] if ann['image_id'] == ref_image_id), None)
        if ref_ann is None:
            print(f"No annotation found for reference image ID {ref_image_id}")
            continue

        reference_keypoints = np.array(ref_ann['keypoints']).reshape(-1, 3)[:, :2]

        for ann in coco_data['annotations']:
            image_id = ann['image_id']
            image_info = next((img for img in coco_data['images'] if img['id'] == image_id), None)
            if image_info is None:
                print(f"No image info found for image ID {image_id}")
                continue

            image_filename = image_info['file_name']
            image_path = os.path.join(image_folder, image_filename)

            if not os.path.exists(image_path):
                print(f"Image not found: {image_path}")
                continue

            try:
                image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
                if image is None:
                    print(f"Failed to read image: {image_path}")
                    continue
                
                image = ensure_rgba(image)

                keypoints = np.array(ann['keypoints']).reshape(-1, 3)[:, :2]

                rle = ann['segmentation']
                mask = mask_utils.decode(rle)

                _, widths = divide_mask_by_centerline(mask, keypoints)
                avg_width = int(np.mean(widths))

                total_length = np.sum(np.sqrt(np.sum(np.diff(keypoints, axis=0)**2, axis=1)))
                
                straightened = straighten_image(image, keypoints, mask, total_length, avg_width)
                print(f"Straightened image width: {straightened.shape[1]}")

                if scale:
                    reference_curve, scale_factor = generate_reference_curve(reference_keypoints, num_points=10000, target_length=straightened.shape[1])
                else:
                    reference_curve, scale_factor = generate_reference_curve(reference_keypoints, num_points=10000)

                warped, warped_filled, edge = warp_straightened_image(straightened, reference_curve, avg_width, scale_factor)

                if warped_filled.shape[0] > output_height or warped_filled.shape[1] > output_width:
                    scale = min(output_height / warped_filled.shape[0], output_width / warped_filled.shape[1])
                    new_size = (int(warped_filled.shape[1] * scale), int(warped_filled.shape[0] * scale))
                    warped_filled = cv2.resize(warped_filled, new_size, interpolation=cv2.INTER_AREA)
                    edge = cv2.resize(edge, new_size, interpolation=cv2.INTER_NEAREST)

                # Create a white background
                output = np.ones((output_height, output_width, 3), dtype=np.uint8) * 255

                y_offset = (output_height - warped_filled.shape[0]) // 2
                x_offset = (output_width - warped_filled.shape[1]) // 2
                
                # Ensure warped_filled has 3 channels (BGR)
                if warped_filled.shape[2] == 4:
                    # If it's RGBA, blend it with white background
                    alpha = warped_filled[:, :, 3] / 255.0
                    warped_filled_rgb = warped_filled[:, :, :3]
                    white_bg = np.ones_like(warped_filled_rgb) * 255
                    warped_filled = (alpha[:, :, np.newaxis] * warped_filled_rgb + 
                                     (1 - alpha[:, :, np.newaxis]) * white_bg).astype(np.uint8)
                elif warped_filled.shape[2] != 3:
                    raise ValueError(f"Unexpected number of channels: {warped_filled.shape[2]}")
                
                output[y_offset:y_offset+warped_filled.shape[0], x_offset:x_offset+warped_filled.shape[1]] = warped_filled

                output_filename = f"{os.path.splitext(image_filename)[0]}_warped_ref_image{ref_image_id}_.jpg"
                output_path = os.path.join(output_folder, output_filename)
                cv2.imwrite(output_path, output, [int(cv2.IMWRITE_JPEG_QUALITY), 95])
                print(f"Processed and saved: {output_filename}")

                frame = np.zeros((output_height, output_width), dtype=np.uint8)
                frame[y_offset:y_offset+edge.shape[0], x_offset:x_offset+edge.shape[1]] = edge
                frame_images.append(frame)

            except Exception as e:
                print(f"Error processing image {image_filename}: {str(e)}")

    return frame_images

# %%
# # Usage
# json_file_path = r'D:\Personal_Project\snake_straightening\data\isIDD_v2\label\all_1024\all_annotations_easy_1024.json'
# image_folder = r'D:\Personal_Project\snake_straightening\graph_generate\KGOT_sample'
# output_folder = r'D:\Personal_Project\snake_straightening\graph_generate\trial'

# circulate_image_from_coco(json_file_path, image_folder, output_folder)

# %% [markdown]
# Straightening image and output

# %%
import json
import os   

def load_and_preprocess_image(image_path):
    if not os.path.exists(image_path):
        print(f"Error: Image file not found: {image_path}")
        return None
    
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if image is None:
        print(f"Error: Unable to load image: {image_path}")
        return None
    
    if len(image.shape) == 2:  # Grayscale image
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGBA)
    elif image.shape[2] == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGBA)
    elif image.shape[2] == 4:
        image = cv2.cvtColor(image, cv2.COLOR_BGRA2RGBA)
    
    return image

def straighten_images_from_coco(json_file_path, image_folder, output_folder):
    with open(json_file_path, 'r') as f:
        coco_data = json.load(f)

    os.makedirs(output_folder, exist_ok=True)

    for ann in coco_data['annotations']:
        image_id = ann['image_id']
        image_info = next((img for img in coco_data['images'] if img['id'] == image_id), None)
        if image_info is None:
            print(f"Error: No image info found for image_id: {image_id}")
            continue
        
        image_filename = image_info['file_name']
        image_path = os.path.join(image_folder, image_filename)
        image = load_and_preprocess_image(image_path)
        
        if image is None:
            continue  # Skip this image and move to the next one
        
        keypoints = np.array(ann['keypoints']).reshape(-1, 3)[:, :2]
        mask = mask_utils.decode(ann['segmentation'])

        _, widths = divide_mask_by_centerline(mask, keypoints)
        avg_width = int(np.mean(widths))
        total_length = np.sum(np.sqrt(np.sum(np.diff(keypoints, axis=0)**2, axis=1)))

        straightened = straighten_image(image, keypoints, mask, total_length, avg_width)

        output_filename = f"{os.path.splitext(image_filename)[0]}_straightened.png"
        output_path = os.path.join(output_folder, output_filename)
        save_straightened_image(straightened, output_path)

        print(f"Processed and saved: {output_filename}")

# %%
# # Usage
image_folder = r'D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train'
output_folder = r'D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\kgot_aug'
coco_json = r'D:\Personal_Project\snake_straightening\data\isIDD_v2\label\all_1024\all_annotations_1024.json'

circulate_image_from_coco(coco_json, image_folder, output_folder, output_width=1024, output_height=1024, scale=True)
# Out:
# Image not found: D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train\gilly_2020_02_243.jpg
# Straightened image width: 1152
# Original length: 1183.44
# Target length: 1152
# New length: 1151.79
# Scale factor: 0.97
# Processed and saved: gilly_2020_05_341_warped_ref_image1_.jpg
# Error processing image gilly_2020_05_341.jpg: could not broadcast input array from shape (628,381,4) into shape (628,381)
# Image not found: D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train\northby__219.jpg
# Image not found: D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train\olivia_217.jpg
# Image not found: D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train\sonic_091.jpg
# Image not found: D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train\suzanne_178.jpg
# Image not found: D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train\tsukki_276.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 6
#       3 output_folder = r'D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\kgot_aug'
#       4 coco_json = r'D:\Personal_Project\snake_straightening\data\isIDD_v2\label\all_1024\all_annotations_1024.json'
# ----> 6 circulate_image_from_coco(coco_json, image_folder, output_folder, output_width=1024, output_height=1024, scale=True)
#
# Cell In[36], line 46, in circulate_image_from_coco(json_file_path, image_folder, output_folder, output_width, output_height, scale)
#      43 rle = ann['segmentation']
#      44 mask = mask_utils.decode(rle)
# ---> 46 _, widths = divide_mask_by_centerline(mask, keypoints)
#      47 avg_width = int(np.mean(widths))
#      49 total_length = np.sum(np.sqrt(np.sum(np.diff(keypoints, axis=0)**2, axis=1)))
#
# Cell In[34], line 76, in divide_mask_by_centerline(mask, centerline, num_segments)
#      75 def divide_mask_by_centerline(mask, centerline, num_segments=10):
# ---> 76     segment_masks, widths = process_centerline(mask, centerline, num_segments, create_masks=True)
#      77     return segment_masks, widths
#
# Cell In[34], line 67, in process_centerline(mask, centerline, num_segments, create_masks)
#      64 end_point = selected_points[i + 1]
#      65 normal = normals[indices[i]]
# ---> 67 segment_mask, width = process_segment(mask, start_point, end_point, normal, create_masks)
#      69 if create_masks:
#      70     segment_masks.append(segment_mask)
#
# Cell In[34], line 51, in process_segment(mask, start_point, end_point, normal, create_mask)
#      48 rr, cc = line(int(start_point[1]), int(start_point[0]), int(end_point[1]), int(end_point[0]))
#      50 for r, c in zip(rr, cc):
# ---> 51     width = calculate_width_and_fill_mask(mask, (c, r), normal, segment_mask)
#      52     segment_widths.append(width)
#      54 return segment_mask, np.mean(segment_widths)
#
# Cell In[34], line 36, in calculate_width_and_fill_mask(mask, point, normal, segment_mask)
#      34 current_point = np.array(point, dtype=float)
#      35 while True:
# ---> 36     x, y = np.round(current_point).astype(int)
#      37     if x < 0 or x >= mask.shape[1] or y < 0 or y >= mask.shape[0] or mask[y, x] == 0:
#      38         break
#
# KeyboardInterrupt:

# %%
# import os
# import shutil
# import pandas as pd

# # Define paths
# csv_file = r"D:\Personal_Project\snake_straightening\data\classification_dataset_traditional_aug_no_bg\data_class_imbalance.csv"
# source_folder = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train"
# destination_folder = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\kgot_aug"

# # Create destination folder if it doesn't exist
# os.makedirs(destination_folder, exist_ok=True)

# # Read the CSV file
# df = pd.read_csv(csv_file)

# # Get the list of image files in the source folder
# source_files = set(os.listdir(source_folder))

# # Counter for moved files
# moved_count = 0

# # Iterate through the image_path column
# for image_path in df['image_path']:
#     # Get just the filename from the path
#     image_filename = os.path.basename(image_path)
    
#     # Check if the file exists in the source folder
#     if image_filename in source_files:
#         # Construct full paths
#         source_path = os.path.join(source_folder, image_filename)
#         dest_path = os.path.join(destination_folder, image_filename)
        
#         # Move the file
#         shutil.move(source_path, dest_path)
#         moved_count += 1
#         print(f"Moved: {image_filename}")

# print(f"Total files moved: {moved_count}")
# Out:
# Moved: 2022_neonate_dump_192.jpg
# Moved: 2022_neonate_dump_030.jpg
# Moved: 2022_neonate_dump_034.jpg
# Moved: 2022_neonate_dump_035.jpg
# Moved: 2022_neonate_dump_162.jpg
# Moved: 2022_neonate_dump_191.jpg
# Moved: 2022_neonate_dump_180.jpg
# Moved: 2022_neonate_dump_251.jpg
# Moved: anju_100.jpg
# Moved: anju_271.jpg
# Moved: anju_257.jpg
# Moved: anju_181.jpg
# Moved: anju_259.jpg
# Moved: anju_224.jpg
# Moved: anju_072.jpg
# Moved: anju_285.jpg
# Moved: anju_045.jpg
# Moved: anju_314.jpg
# Moved: anju_013.jpg
# Moved: anju_169.jpg
# Moved: anju_154.jpg
# Moved: anju_249.jpg
# Moved: ariel_01_(40)_255.jpg
# Moved: ariel_01_(40)_300.jpg
# Moved: ariel_01_(40)_136.jpg
# Moved: ariel_01_(40)_225.jpg
# Moved: armin_(14)_279.jpg
# Moved: armin_(14)_038.jpg
# Moved: armin_(14)_040.jpg
# Moved: armin_(14)_252.jpg
# Moved: armin_(14)_107.jpg
# Moved: armin_(14)_253.jpg
# Moved: armin_(14)_311.jpg
# Moved: belle_061.jpg
# Moved: belle_223.jpg
# Moved: belle_183.jpg
# Moved: brock_(26)_334.jpg
# Moved: brock_(26)_041.jpg
# Moved: brock_(26)_289.jpg
# Moved: brock_(26)_132.jpg
# Moved: brock_2021_07_188.jpg
# Moved: brock_07_101.jpg
# Moved: brock_07_052.jpg
# Moved: brock_(26)_078.jpg
# Moved: cavatappi_170.jpg
# Moved: cavatappi_207.jpg
# Moved: cavatappi_104.jpg
# Moved: cavatappi_113.jpg
# Moved: cavatappi_284.jpg
# Moved: cavatappi_064.jpg
# Moved: cavatappi_119.jpg
# Moved: cavatappi_206.jpg
# Moved: cavatappi_023.jpg
# Moved: cavatappi_145.jpg
# Moved: cavatappi_215.jpg
# Moved: cup_309.jpg
# Moved: cup_069.jpg
# Moved: cup_329.jpg
# Moved: cup_070.jpg
# Moved: cup_125.jpg
# Moved: cup_213.jpg
# Moved: dumbbell_254.jpg
# Moved: dumbbell_360.jpg
# Moved: dumbbell_274.jpg
# Moved: dumbbell_098.jpg
# Moved: dumbbell_148.jpg
# Moved: dumbbell_205.jpg
# Moved: eren_jaeger_230.jpg
# Moved: gilly_2020_08_046.jpg
# Moved: gilly_2020_07_171.jpg
# Moved: gilly_2020_08_120.jpg
# Moved: gilly_2020_05_350.jpg
# Moved: gilly_2020_08_246.jpg
# Moved: gilly_2020_07_044.jpg
# Moved: gilly_2020_08_216.jpg
# Moved: gilly_2020_07_142.jpg
# Moved: gilly_2020_08_331.jpg
# Moved: gilly_2020_02_007.jpg
# Moved: gilly_2020_05_049.jpg
# Moved: gilly_2020_05_341.jpg
# Moved: historia_326.jpg
# Moved: honey_006.jpg
# Moved: honey_067.jpg
# Moved: honey_258.jpg
# Moved: honey_239.jpg
# Moved: honey_010.jpg
# Moved: honey_080.jpg
# Moved: honey_095.jpg
# Moved: honey_121.jpg
# Moved: honey_111.jpg
# Moved: honey_026.jpg
# Moved: jetta_025.jpg
# Moved: jetta_352.jpg
# Moved: kiyoko_037.jpg
# Moved: kiyoko_105.jpg
# Moved: lena_065.jpg
# Moved: lena_159.jpg
# Moved: levi_063.jpg
# Moved: levi_005.jpg
# Moved: master_chief_310.jpg
# Moved: northby__071.jpg
# Moved: orecchiette_304.jpg
# Moved: pieck_270.jpg
# Moved: pinkman_047.jpg
# Moved: pinkman_082.jpg
# Moved: pinkman_264.jpg
# Moved: queenie_347.jpg
# Moved: queenie_2021_09_330.jpg
# Moved: queenie_2021_09_141.jpg
# Moved: queenie_2021_06_288.jpg
# Moved: queenie_2021_06_168.jpg
# Moved: queenie_2021_09_036.jpg
# Moved: queenie_2021_09_081.jpg
# Moved: sansa_115.jpg
# Moved: sansa_199.jpg
# Moved: sansa_237.jpg
# Moved: sansa_055.jpg
# Moved: sansa_129.jpg
# Moved: sansa_002.jpg
# Moved: sansa_123.jpg
# Moved: sansa_282.jpg
# Moved: sansa_236.jpg
# Moved: sansa_228.jpg
# Moved: sansa_337.jpg
# Moved: sansa_077.jpg
# Moved: smoke_079.jpg
# Moved: suzanne_058.jpg
# Moved: suzanne_174.jpg
# Moved: suzanne_351.jpg
# Moved: suzanne_197.jpg
# Moved: troi_263.jpg
# Moved: unk_neo_2021_01_(11)_066.jpg
# Moved: unk_neo_2021_05_031.jpg
# Moved: unk_neo_2021_01_(11)_172.jpg
# Moved: unk_neo_2021_03_(3)_294.jpg
# Moved: unk_neo_2021_01_(11)_297.jpg
# Moved: unk_neo_2021_01_(11)_118.jpg
# Moved: unk_neo_2021_01_(11)_022.jpg
# Moved: wisp_176.jpg
# Moved: northern_cottonmouth_5946013.jpg
# Moved: northern_cottonmouth_5808713.jpg
# Moved: boa_constrictor_29257736.jpg
# Moved: gray_ratsnake_15596538.jpg
# Moved: boa_constrictor_29399115.jpg
# Moved: northern_cottonmouth_6480934.jpg
# Moved: grass_snake_19797206.jpg
# Moved: northern_cottonmouth_5910126.jpg
# Moved: gray_ratsnake_15951775.jpg
# Moved: gray_ratsnake_17019400.jpg
# Moved: boa_constrictor_29376899.jpg
# Moved: eastern_milkesnake_16118667.jpg
# Moved: northern_cottonmouth_5667744.jpg
# Moved: boa_constrictor_29401939.jpg
# Moved: eastern_milkesnake_16666291.jpg
# Moved: grass_snake_20106904.jpg
# Moved: eastern_copperhead_8321670.jpg
# Moved: gray_ratsnake_17094894.jpg
# Moved: northern_cottonmouth_6438730.jpg
# Moved: northern_cottonmouth_5733880.jpg
# Moved: grass_snake_20361102.jpg
# Moved: gray_ratsnake_15618425.jpg
# Moved: gray_ratsnake_16949716.jpg
# Moved: northern_cottonmouth_6151094.jpg
# Moved: northern_cottonmouth_5676507.jpg
# Moved: boa_constrictor_27705611.jpg
# Moved: eastern_copperhead_8485749.jpg
# Moved: eastern_milkesnake_17045031.jpg
# Moved: gray_ratsnake_16643938.jpg
# Moved: northern_cottonmouth_6611142.jpg
# Moved: eastern_copperhead_8047466.jpg
# Moved: boa_constrictor_29815015.jpg
# Moved: gray_ratsnake_15775114.jpg
# Moved: northern_cottonmouth_5705707.jpg
# Moved: boa_constrictor_28099013.jpg
# Moved: boa_constrictor_27459709.jpg
# Moved: northern_cottonmouth_5781171.jpg
# Moved: eastern_milkesnake_16440934.jpg
# Moved: northern_cottonmouth_6730401.jpg
# Moved: eastern_milkesnake_16324735.jpg
# Moved: eastern_copperhead_7438767.jpg
# Moved: eastern_copperhead_8370915.jpg
# Moved: eastern_copperhead_7761506.jpg
# Moved: northern_cottonmouth_5910406.jpg
# Moved: gray_ratsnake_16591672.jpg
# Moved: gray_ratsnake_15408921.jpg
# Moved: grass_snake_20998135.jpg
# Moved: grass_snake_21114768.jpg
# Moved: northern_cottonmouth_5849799.jpg
# Moved: grass_snake_21213712.jpg
# Moved: eastern_milkesnake_15861860.jpg
# Moved: earthworm_032.jpg
# Moved: northern_cottonmouth_6621857.jpg
# Moved: gray_ratsnake_16536853.jpg
# Moved: eastern_milkesnake_16801609.jpg
# Moved: eastern_milkesnake_17361970.jpg
# Moved: eastern_milkesnake_16505422.jpg
# Moved: northern_cottonmouth_6505353.jpg
# Moved: eastern_copperhead_7970189.jpg
# Moved: eastern_copperhead_7669382.jpg
# Moved: grass_snake_22142932.jpg
# Moved: grass_snake_21783186.jpg
# Moved: northern_cottonmouth_5759167.jpg
# Moved: grass_snake_21598581.jpg
# Moved: eastern_copperhead_8168957.jpg
# Moved: gray_ratsnake_15810124.jpg
# Moved: boa_constrictor_28682210.jpg
# Moved: gray_ratsnake_16091267.jpg
# Moved: eastern_milkesnake_17151819.jpg
# Moved: earthworm_007.jpg
# Moved: gray_ratsnake_15783707.jpg
# Moved: eastern_copperhead_7950215.jpg
# Moved: northern_cottonmouth_6730397.jpg
# Moved: boa_constrictor_27796896.jpg
# Moved: boa_constrictor_27717269.jpg
# Moved: eastern_copperhead_7970348.jpg
# Moved: gray_ratsnake_16220014.jpg
# Moved: gray_ratsnake_16100993.jpg
# Moved: northern_cottonmouth_5940010.jpg
# Moved: northern_cottonmouth_6490420.jpg
# Moved: northern_cottonmouth_6327963.jpg
# Moved: eastern_copperhead_7426647.jpg
# Moved: boa_constrictor_29527523.jpg
# Moved: boa_constrictor_29787924.jpg
# Moved: gray_ratsnake_16176038.jpg
# Moved: eastern_milkesnake_16921229.jpg
# Moved: northern_cottonmouth_6674007.jpg
# Moved: grass_snake_21510627.jpg
# Moved: eastern_milkesnake_16764069.jpg
# Moved: earthworm_017.jpg
# Moved: eastern_milkesnake_16829072.jpg
# Moved: northern_cottonmouth_6116213.jpg
# Moved: grass_snake_21909861.jpg
# Moved: northern_cottonmouth_6679743.jpg
# Moved: gray_ratsnake_17040699.jpg
# Moved: gray_ratsnake_16732608.jpg
# Moved: northern_cottonmouth_6723886.jpg
# Moved: gray_ratsnake_15627669.jpg
# Moved: boa_constrictor_28956834.jpg
# Moved: northern_cottonmouth_6443715.jpg
# Moved: eastern_copperhead_7558432.jpg
# Moved: grass_snake_21141456.jpg
# Moved: earthworm_018.jpg
# Moved: earthworm_044.jpg
# Moved: boa_constrictor_29689615.jpg
# Moved: eastern_copperhead_8002529.jpg
# Moved: eastern_milkesnake_17101240.jpg
# Moved: northern_cottonmouth_6525971.jpg
# Moved: eastern_copperhead_8010669.jpg
# Moved: northern_cottonmouth_6387781.jpg
# Moved: grass_snake_21016788.jpg
# Moved: grass_snake_21292262.jpg
# Moved: earthworm_005.jpg
# Moved: boa_constrictor_27171080.jpg
# Moved: northern_cottonmouth_6150431.jpg
# Moved: earthworm_033.jpg
# Moved: eastern_milkesnake_16070387.jpg
# Moved: grass_snake_21938930.jpg
# Moved: eastern_copperhead_8019835.jpg
# Moved: eastern_copperhead_8207907.jpg
# Moved: grass_snake_21259158.jpg
# Moved: northern_cottonmouth_6210220.jpg
# Moved: earthworm_042.jpg
# Moved: northern_cottonmouth_6124670.jpg
# Moved: eastern_copperhead_8027995.jpg
# Moved: eastern_copperhead_8416340.jpg
# Moved: eastern_milkesnake_16223757.jpg
# Moved: boa_constrictor_27692244.jpg
# Moved: eastern_milkesnake_15897449.jpg
# Moved: eastern_milkesnake_16804923.jpg
# Moved: northern_cottonmouth_5775752.jpg
# Moved: northern_cottonmouth_6102943.jpg
# Moved: earthworm_002.jpg
# Moved: northern_cottonmouth_5841586.jpg
# Moved: grass_snake_20723589.jpg
# Moved: northern_cottonmouth_5677705.jpg
# Moved: northern_cottonmouth_6523467.jpg
# Moved: grass_snake_20877521.jpg
# Moved: northern_cottonmouth_5709443.jpg
# Moved: grass_snake_21275856.jpg
# Moved: eastern_copperhead_8039048.jpg
# Moved: gray_ratsnake_15580601.jpg
# Moved: grass_snake_21940125.jpg
# Moved: eastern_copperhead_8047829.jpg
# Moved: boa_constrictor_27089674.jpg
# Moved: gray_ratsnake_16286834.jpg
# Moved: earthworm_024.jpg
# Moved: eastern_milkesnake_16604773.jpg
# Moved: gray_ratsnake_15401814.jpg
# Moved: eastern_milkesnake_16399155.jpg
# Moved: eastern_milkesnake_16686370.jpg
# Moved: boa_constrictor_26866106.jpg
# Moved: eastern_milkesnake_17304497.jpg
# Moved: grass_snake_20505365.jpg
# Moved: gray_ratsnake_15278254.jpg
# Moved: gray_ratsnake_16508752.jpg
# Moved: grass_snake_21114775.jpg
# Moved: northern_cottonmouth_6427645.jpg
# Moved: gray_ratsnake_15216686.jpg
# Moved: eastern_milkesnake_17199986.jpg
# Moved: eastern_milkesnake_15860661.jpg
# Moved: grass_snake_21141533.jpg
# Moved: eastern_milkesnake_16669455.jpg
# Moved: grass_snake_22074895.jpg
# Moved: eastern_milkesnake_17388005.jpg
# Moved: boa_constrictor_29828923.jpg
# Moved: eastern_copperhead_7513692.jpg
# Moved: gray_ratsnake_15567437.jpg
# Moved: grass_snake_19779729.jpg
# Moved: eastern_milkesnake_16556686.jpg
# Moved: northern_cottonmouth_6621854.jpg
# Moved: northern_cottonmouth_6618085.jpg
# Moved: earthworm_060.jpg
# Moved: eastern_milkesnake_17772689.jpg
# Moved: eastern_copperhead_8045581.jpg
# Moved: grass_snake_21940304.jpg
# Moved: boa_constrictor_28962944.jpg
# Moved: grass_snake_21053324.jpg
# Moved: gray_ratsnake_16712584.jpg
# Moved: northern_cottonmouth_6427648.jpg
# Moved: northern_cottonmouth_5781846.jpg
# Moved: northern_cottonmouth_5706246.jpg
# Moved: eastern_copperhead_7964811.jpg
# Moved: eastern_milkesnake_16261423.jpg
# Moved: eastern_milkesnake_17713230.jpg
# Moved: boa_constrictor_29143273.jpg
# Moved: northern_cottonmouth_5777793.jpg
# Moved: eastern_milkesnake_17652640.jpg
# Moved: eastern_milkesnake_16134633.jpg
# Moved: gray_ratsnake_16675110.jpg
# Moved: gray_ratsnake_16791286.jpg
# Moved: grass_snake_20100461.jpg
# Moved: eastern_copperhead_8331904.jpg
# Moved: gray_ratsnake_16437906.jpg
# Moved: eastern_milkesnake_16268039.jpg
# Moved: earthworm_011.jpg
# Moved: northern_cottonmouth_6451322.jpg
# Moved: eastern_copperhead_7862941.jpg
# Moved: grass_snake_21275848.jpg
# Moved: eastern_milkesnake_17205673.jpg
# Moved: eastern_milkesnake_15998710.jpg
# Moved: eastern_copperhead_7562769.jpg
# Moved: boa_constrictor_29498074.jpg
# Moved: gray_ratsnake_15333586.jpg
# Moved: earthworm_057.jpg
# Moved: boa_constrictor_28537638.jpg
# Moved: boa_constrictor_29522509.jpg
# Moved: northern_cottonmouth_6495330.jpg
# Moved: grass_snake_20199991.jpg
# Moved: eastern_milkesnake_16472987.jpg
# Moved: grass_snake_21114767.jpg
# Moved: earthworm_062.jpg
# Moved: earthworm_003.jpg
# Moved: eastern_copperhead_7625892.jpg
# Moved: eastern_copperhead_7620260.jpg
# Moved: boa_constrictor_27677245.jpg
# Moved: northern_cottonmouth_5767199.jpg
# Moved: eastern_copperhead_7954542.jpg
# Moved: eastern_copperhead_8305170.jpg
# Moved: gray_ratsnake_15328804.jpg
# Moved: gray_ratsnake_15117897.jpg
# Moved: eastern_copperhead_7426520.jpg
# Moved: grass_snake_22021410.jpg
# Moved: gray_ratsnake_15693269.jpg
# Moved: eastern_copperhead_7439659.jpg
# Moved: gray_ratsnake_15765452.jpg
# Moved: boa_constrictor_27021503.jpg
# Moved: grass_snake_19863792.jpg
# Moved: northern_cottonmouth_6487227.jpg
# Moved: boa_constrictor_29527690.jpg
# Moved: gray_ratsnake_15976944.jpg
# Moved: grass_snake_21382677.jpg
# Moved: eastern_copperhead_7475896.jpg
# Moved: eastern_milkesnake_16189436.jpg
# Moved: eastern_copperhead_8188096.jpg
# Moved: eastern_copperhead_8065733.jpg
# Moved: eastern_milkesnake_16299927.jpg
# Moved: eastern_milkesnake_16508830.jpg
# Moved: earthworm_058.jpg
# Moved: gray_ratsnake_15442102.jpg
# Moved: gray_ratsnake_15891429.jpg
# Moved: grass_snake_21114779.jpg
# Moved: northern_cottonmouth_6442823.jpg
# Moved: grass_snake_21020312.jpg
# Moved: boa_constrictor_28406825.jpg
# Moved: grass_snake_22215693.jpg
# Moved: earthworm_031.jpg
# Moved: northern_cottonmouth_5970707.jpg
# Moved: boa_constrictor_28968884.jpg
# Moved: eastern_copperhead_8485320.jpg
# Moved: northern_cottonmouth_6527064.jpg
# Moved: grass_snake_20421118.jpg
# Moved: eastern_copperhead_8104153.jpg
# Moved: eastern_copperhead_8039199.jpg
# Moved: gray_ratsnake_16563731.jpg
# Moved: eastern_milkesnake_16711154.jpg
# Moved: boa_constrictor_27506183.jpg
# Moved: gray_ratsnake_15260352.jpg
# Moved: eastern_milkesnake_17097885.jpg
# Moved: eastern_milkesnake_17138262.jpg
# Moved: boa_constrictor_28737587.jpg
# Moved: northern_cottonmouth_5678559.jpg
# Moved: northern_cottonmouth_6245321.jpg
# Moved: eastern_milkesnake_17174406.jpg
# Moved: gray_ratsnake_15117865.jpg
# Moved: eastern_milkesnake_16766684.jpg
# Moved: grass_snake_20150177.jpg
# Moved: boa_constrictor_27344586.jpg
# Moved: gray_ratsnake_16371414.jpg
# Moved: northern_cottonmouth_5841906.jpg
# Moved: earthworm_004.jpg
# Moved: boa_constrictor_29173329.jpg
# Moved: eastern_milkesnake_16186787.jpg
# Moved: grass_snake_21275819.jpg
# Moved: eastern_copperhead_7873665.jpg
# Moved: grass_snake_21209210.jpg
# Moved: gray_ratsnake_15105352.jpg
# Moved: eastern_copperhead_8074515.jpg
# Moved: grass_snake_20999896.jpg
# Moved: northern_cottonmouth_6703856.jpg
# Moved: gray_ratsnake_16738420.jpg
# Moved: eastern_milkesnake_16668076.jpg
# Moved: grass_snake_21203585.jpg
# Moved: northern_cottonmouth_6165789.jpg
# Moved: eastern_copperhead_7767344.jpg
# Moved: gray_ratsnake_15791713.jpg
# Moved: eastern_milkesnake_17205671.jpg
# Moved: eastern_copperhead_7620042.jpg
# Moved: eastern_copperhead_8334734.jpg
# Moved: gray_ratsnake_15260360.jpg
# Moved: northern_cottonmouth_6043325.jpg
# Moved: boa_constrictor_29527999.jpg
# Moved: northern_cottonmouth_5769889.jpg
# Moved: grass_snake_20325579.jpg
# Moved: earthworm_027.jpg
# Moved: earthworm_037.jpg
# Moved: eastern_milkesnake_16298534.jpg
# Moved: earthworm_013.jpg
# Moved: gray_ratsnake_17011615.jpg
# Moved: earthworm_010.jpg
# Moved: grass_snake_21114760.jpg
# Moved: northern_cottonmouth_6256009.jpg
# Moved: northern_cottonmouth_6425877.jpg
# Moved: grass_snake_22100224.jpg
# Moved: grass_snake_22237308.jpg
# Moved: grass_snake_22189796.jpg
# Moved: boa_constrictor_27171083.jpg
# Moved: eastern_milkesnake_17101842.jpg
# Moved: boa_constrictor_28472426.jpg
# Moved: boa_constrictor_28432420.jpg
# Moved: eastern_copperhead_7666308.jpg
# Moved: northern_cottonmouth_5995208.jpg
# Moved: gray_ratsnake_16783393.jpg
# Moved: grass_snake_20429256.jpg
# Moved: eastern_copperhead_7795940.jpg
# Moved: gray_ratsnake_15522631.jpg
# Moved: gray_ratsnake_15723666.jpg
# Moved: eastern_copperhead_7778783.jpg
# Moved: gray_ratsnake_15886214.jpg
# Total files moved: 458

# %%
# import os
# import shutil
# import pandas as pd

# # Define paths
# csv_file = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\data_class_imbalance.csv"
# train_folder = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train_og"
# kgot_aug_folder = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train"

# # Create kgot_aug folder if it doesn't exist
# os.makedirs(kgot_aug_folder, exist_ok=True)

# # Read the CSV file
# df = pd.read_csv(csv_file)

# # Filter the DataFrame to include only rows where subset is "train"
# df_train = df[df['subset'] == 'train']

# # Get the list of image files in the CSV for the train subset
# csv_files = set(df_train['image_path'])

# # Counter for moved files
# moved_to_kgot_count = 0
# moved_to_train_count = 0

# # Step 1: Move files from train to kgot_aug if they're in the CSV
# for filename in os.listdir(train_folder):
#     if filename in csv_files:
#         source_path = os.path.join(train_folder, filename)
#         dest_path = os.path.join(kgot_aug_folder, filename)
#         shutil.move(source_path, dest_path)
#         moved_to_kgot_count += 1
#         print(f"Moved to kgot_aug: {filename}")

# print(f"Total files moved to kgot_aug: {moved_to_kgot_count}")

# # Step 2: Move files from kgot_aug back to train if they're not in the CSV
# for filename in os.listdir(kgot_aug_folder):
#     if filename not in csv_files:
#         source_path = os.path.join(kgot_aug_folder, filename)
#         dest_path = os.path.join(train_folder, filename)
#         shutil.move(source_path, dest_path)
#         moved_to_train_count += 1
#         print(f"Moved back to train: {filename}")

# print(f"Total files moved back to train: {moved_to_train_count}")

# # Print some statistics
# print(f"Files in train folder: {len(os.listdir(train_folder))}")
# print(f"Files in kgot_aug folder: {len(os.listdir(kgot_aug_folder))}")
# Out:
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image100_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image101_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image102_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image103_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image104_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image105_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image106_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image107_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image108_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image109_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image10_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image110_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image111_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image112_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image113_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image114_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image115_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image116_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image117_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image118_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image119_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image11_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image120_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image121_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image122_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image123_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image124_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image125_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image126_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image127_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image128_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image129_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image12_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image130_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image131_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image132_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image133_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image134_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image135_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image136_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image137_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image138_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image139_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image13_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image140_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image141_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image142_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image143_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image144_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image145_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image146_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image147_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image148_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image149_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image14_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image150_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image151_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image152_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image153_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image154_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image155_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image156_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image157_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image158_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image159_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image15_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image160_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image161_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image162_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image163_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image164_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image165_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image166_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image167_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image168_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image169_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image16_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image170_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image171_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image172_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image173_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image174_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image175_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image176_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image177_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image178_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image179_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image17_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image180_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image181_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image182_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image183_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image184_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image185_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image186_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image187_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image188_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image189_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image18_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image190_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image192_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image193_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image194_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image195_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image196_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image197_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image198_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image199_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image19_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image1_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image200_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image202_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image203_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image205_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image206_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image207_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image208_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image209_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image20_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image210_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image211_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image212_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image214_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image216_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image217_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image218_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image21_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image222_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image223_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image224_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image229_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image22_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image231_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image232_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image233_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image234_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image235_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image237_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image238_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image239_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image23_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image240_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image241_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image242_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image243_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image244_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image245_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image247_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image248_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image249_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image24_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image250_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image251_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image257_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image259_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image260_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image263_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image264_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image266_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image267_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image268_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image269_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image26_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image270_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image271_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image272_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image273_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image274_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image276_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image278_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image279_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image27_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image280_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image281_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image282_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image284_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image286_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image287_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image288_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image28_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image290_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image291_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image292_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image293_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image294_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image295_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image296_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image297_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image298_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image299_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image2_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image300_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image301_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image302_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image304_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image306_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image307_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image308_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image309_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image30_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image310_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image311_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image312_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image313_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image314_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image316_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image318_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image320_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image324_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image325_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image326_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image327_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image328_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image329_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image330_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image331_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image332_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image333_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image334_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image336_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image337_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image338_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image339_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image341_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image342_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image346_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image347_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image349_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image350_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image351_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image352_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image353_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image355_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image357_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image359_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image360_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image361_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image37_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image38_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image39_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image3_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image40_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image41_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image43_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image44_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image45_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image46_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image47_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image48_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image49_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image4_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image50_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image52_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image53_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image54_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image55_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image56_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image57_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image58_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image59_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image5_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image60_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image61_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image62_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image63_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image64_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image65_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image66_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image67_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image68_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image69_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image6_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image70_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image71_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image72_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image73_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image74_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image75_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image76_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image77_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image78_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image79_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image7_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image80_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image81_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image82_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image83_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image84_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image85_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image86_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image87_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image88_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image89_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image8_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image90_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image91_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image92_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image93_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image94_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image95_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image96_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image97_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image98_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image99_.jpg
# Moved to kgot_aug: 2022_neonate_dump_030_warped_ref_image9_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image100_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image101_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image102_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image103_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image104_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image105_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image106_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image107_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image108_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image109_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image10_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image110_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image111_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image112_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image113_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image114_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image115_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image116_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image117_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image118_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image119_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image11_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image120_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image121_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image122_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image123_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image124_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image125_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image126_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image127_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image128_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image129_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image12_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image130_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image131_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image132_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image133_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image134_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image135_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image136_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image137_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image138_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image139_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image13_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image140_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image141_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image142_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image143_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image144_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image145_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image146_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image147_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image148_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image149_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image14_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image150_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image151_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image152_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image153_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image154_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image155_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image156_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image157_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image158_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image159_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image15_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image160_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image161_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image162_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image163_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image164_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image165_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image166_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image167_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image168_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image169_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image16_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image170_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image171_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image172_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image173_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image174_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image175_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image176_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image177_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image178_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image179_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image17_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image180_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image181_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image182_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image183_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image184_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image185_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image186_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image187_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image188_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image189_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image18_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image190_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image192_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image193_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image194_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image195_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image196_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image197_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image198_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image199_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image19_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image1_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image200_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image202_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image203_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image205_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image206_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image207_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image208_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image209_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image20_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image210_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image211_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image212_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image214_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image216_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image217_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image218_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image21_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image222_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image223_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image224_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image229_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image22_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image231_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image232_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image233_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image234_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image235_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image237_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image238_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image239_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image23_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image240_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image241_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image242_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image243_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image244_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image245_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image247_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image248_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image249_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image24_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image250_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image251_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image257_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image259_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image260_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image263_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image264_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image266_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image267_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image268_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image269_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image26_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image270_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image271_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image272_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image273_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image274_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image276_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image278_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image279_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image27_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image280_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image281_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image282_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image284_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image286_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image287_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image288_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image28_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image290_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image291_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image292_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image293_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image294_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image295_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image296_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image297_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image298_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image299_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image2_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image300_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image301_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image302_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image304_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image306_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image307_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image308_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image309_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image30_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image310_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image311_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image312_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image313_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image314_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image316_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image318_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image320_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image324_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image325_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image326_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image327_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image328_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image329_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image330_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image331_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image332_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image333_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image334_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image336_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image337_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image338_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image339_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image341_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image342_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image346_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image347_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image349_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image350_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image351_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image352_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image353_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image355_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image357_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image359_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image360_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image361_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image37_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image38_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image39_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image3_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image40_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image41_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image43_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image44_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image45_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image46_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image47_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image48_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image49_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image4_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image50_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image52_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image53_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image54_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image55_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image56_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image57_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image58_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image59_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image5_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image60_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image61_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image62_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image63_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image64_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image65_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image66_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image67_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image68_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image69_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image6_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image70_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image71_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image72_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image73_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image74_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image75_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image76_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image77_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image78_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image79_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image7_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image80_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image81_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image82_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image83_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image84_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image85_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image86_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image87_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image88_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image89_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image8_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image90_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image91_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image92_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image93_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image94_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image95_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image96_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image97_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image98_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image99_.jpg
# Moved to kgot_aug: 2022_neonate_dump_034_warped_ref_image9_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image100_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image101_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image102_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image103_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image104_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image105_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image106_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image107_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image108_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image109_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image10_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image110_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image111_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image112_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image113_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image114_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image115_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image116_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image117_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image118_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image119_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image11_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image120_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image121_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image122_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image123_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image124_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image125_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image126_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image127_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image128_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image129_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image12_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image130_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image131_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image132_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image133_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image134_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image135_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image136_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image137_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image138_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image139_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image13_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image140_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image141_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image142_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image143_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image144_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image145_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image146_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image147_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image148_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image149_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image14_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image150_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image151_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image152_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image153_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image154_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image155_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image156_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image157_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image158_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image159_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image15_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image160_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image161_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image162_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image163_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image164_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image165_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image166_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image167_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image168_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image169_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image16_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image170_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image171_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image172_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image173_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image174_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image175_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image176_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image177_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image178_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image179_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image17_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image180_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image181_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image182_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image183_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image184_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image185_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image186_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image187_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image188_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image189_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image18_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image190_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image192_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image193_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image194_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image195_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image196_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image197_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image198_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image199_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image19_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image1_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image200_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image202_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image203_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image205_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image206_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image207_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image208_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image209_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image20_.jpg
# Moved to kgot_aug: 2022_neonate_dump_035_warped_ref_image210_.jpg
# ...
# Moved back to train: eastern_milkesnake_15477248.jpg
# Moved back to train: eastern_milkesnake_15483576.jpg
# Moved back to train: eastern_milkesnake_15572974.jpg
# Moved back to train: eastern_milkesnake_15591462.jpg
# Moved back to train: eastern_milkesnake_15598610.jpg
# Moved back to train: eastern_milkesnake_15607767.jpg
# Moved back to train: eastern_milkesnake_15607770.jpg
# Moved back to train: eastern_milkesnake_15636607.jpg
# Moved back to train: eastern_milkesnake_15687168.jpg
# Moved back to train: eastern_milkesnake_15706638.jpg
# Moved back to train: eastern_milkesnake_15726694.jpg
# Moved back to train: eastern_milkesnake_15729343.jpg
# Moved back to train: eastern_milkesnake_15738736.jpg
# Moved back to train: eastern_milkesnake_15774438.jpg
# Moved back to train: eastern_milkesnake_15781972.jpg
# Moved back to train: eastern_milkesnake_15793222.jpg
# Moved back to train: eastern_milkesnake_15793530.jpg
# Moved back to train: eastern_milkesnake_15807764.jpg
# Moved back to train: eastern_milkesnake_15813927.jpg
# Moved back to train: eastern_milkesnake_15830705.jpg
# Moved back to train: eastern_milkesnake_15845645.jpg
# Moved back to train: eren_jaeger_029.jpg
# Moved back to train: eren_jaeger_139.jpg
# Moved back to train: eren_jaeger_201.jpg
# Moved back to train: eren_jaeger_230.jpg
# Moved back to train: eren_jaeger_320.jpg
# Moved back to train: eren_jaeger_364.jpg
# Moved back to train: eren_jaeger_400.jpg
# Moved back to train: eren_jaeger_404.jpg
# Moved back to train: eren_jaeger_414.jpg
# Moved back to train: eren_jaeger_420.jpg
# Moved back to train: eren_jaeger_424.jpg
# Moved back to train: eren_jaeger_460.jpg
# Moved back to train: eren_jaeger_499.jpg
# Moved back to train: eren_jaeger_554.jpg
# Moved back to train: eren_jaeger_597.jpg
# Moved back to train: gilly_001.jpg
# Moved back to train: gilly_2020_02_007.jpg
# Moved back to train: gilly_2020_02_012.jpg
# Moved back to train: gilly_2020_02_243.jpg
# Moved back to train: gilly_2020_02_328.jpg
# Moved back to train: gilly_2020_02_366.jpg
# Moved back to train: gilly_2020_02_408.jpg
# Moved back to train: gilly_2020_02_488.jpg
# Moved back to train: gilly_2020_02_522.jpg
# Moved back to train: gilly_2020_02_623.jpg
# Moved back to train: gilly_2020_02_664.jpg
# Moved back to train: gilly_2020_05_049.jpg
# Moved back to train: gilly_2020_05_075.jpg
# Moved back to train: gilly_2020_05_155.jpg
# Moved back to train: gilly_2020_05_341.jpg
# Moved back to train: gilly_2020_05_350.jpg
# Moved back to train: gilly_2020_07_011.jpg
# Moved back to train: gilly_2020_07_044.jpg
# Moved back to train: gilly_2020_07_142.jpg
# Moved back to train: gilly_2020_07_171.jpg
# Moved back to train: gilly_2020_07_256.jpg
# Moved back to train: gilly_2020_07_327.jpg
# Moved back to train: gilly_2020_07_393.jpg
# Moved back to train: gilly_2020_07_409.jpg
# Moved back to train: gilly_2020_07_465.jpg
# Moved back to train: gilly_2020_07_581.jpg
# Moved back to train: gilly_2020_07_592.jpg
# Moved back to train: gilly_2020_07_599.jpg
# Moved back to train: gilly_2020_07_630.jpg
# Moved back to train: gilly_2020_07_673.jpg
# Moved back to train: gilly_2020_08_046.jpg
# Moved back to train: gilly_2020_08_110.jpg
# Moved back to train: gilly_2020_08_120.jpg
# Moved back to train: gilly_2020_08_135.jpg
# Moved back to train: gilly_2020_08_216.jpg
# Moved back to train: gilly_2020_08_246.jpg
# Moved back to train: gilly_2020_08_331.jpg
# Moved back to train: gilly_2020_08_454.jpg
# Moved back to train: gilly_315.jpg
# Moved back to train: grass_snake_19213606.jpg
# Moved back to train: grass_snake_19213608.jpg
# Moved back to train: grass_snake_19217295.jpg
# Moved back to train: grass_snake_19230598.jpg
# Moved back to train: grass_snake_19237783.jpg
# Moved back to train: grass_snake_19267214.jpg
# Moved back to train: grass_snake_19268445.jpg
# Moved back to train: grass_snake_19286004.jpg
# Moved back to train: grass_snake_19311522.jpg
# Moved back to train: grass_snake_19376003.jpg
# Moved back to train: grass_snake_19397979.jpg
# Moved back to train: grass_snake_19426184.jpg
# Moved back to train: grass_snake_19445748.jpg
# Moved back to train: grass_snake_19465976.jpg
# Moved back to train: grass_snake_19489335.jpg
# Moved back to train: grass_snake_19490434.jpg
# Moved back to train: grass_snake_19499619.jpg
# Moved back to train: grass_snake_19510991.jpg
# Moved back to train: grass_snake_19549760.jpg
# Moved back to train: grass_snake_19604232.jpg
# Moved back to train: grass_snake_19610976.jpg
# Moved back to train: grass_snake_19610980.jpg
# Moved back to train: grass_snake_19617353.jpg
# Moved back to train: grass_snake_19653457.jpg
# Moved back to train: grass_snake_19674941.jpg
# Moved back to train: grass_snake_19677451.jpg
# Moved back to train: grass_snake_19684847.jpg
# Moved back to train: grass_snake_19697396.jpg
# Moved back to train: grass_snake_19707040.jpg
# Moved back to train: grass_snake_19710032.jpg
# Moved back to train: grass_snake_19728205.jpg
# Moved back to train: grass_snake_19735548.jpg
# Moved back to train: grass_snake_19735553.jpg
# Moved back to train: grass_snake_19735850.jpg
# Moved back to train: grass_snake_19777538.jpg
# Moved back to train: gray_ratsnake_14421588.jpg
# Moved back to train: gray_ratsnake_14428869.jpg
# Moved back to train: gray_ratsnake_14429390.jpg
# Moved back to train: gray_ratsnake_14440345.jpg
# Moved back to train: gray_ratsnake_14448827.jpg
# Moved back to train: gray_ratsnake_14466485.jpg
# Moved back to train: gray_ratsnake_14467890.jpg
# Moved back to train: gray_ratsnake_14504963.jpg
# Moved back to train: gray_ratsnake_14511401.jpg
# Moved back to train: gray_ratsnake_14539698.jpg
# Moved back to train: gray_ratsnake_14569638.jpg
# Moved back to train: gray_ratsnake_14580238.jpg
# Moved back to train: gray_ratsnake_14627320.jpg
# Moved back to train: gray_ratsnake_14648107.jpg
# Moved back to train: gray_ratsnake_14662537.jpg
# Moved back to train: gray_ratsnake_14691836.jpg
# Moved back to train: gray_ratsnake_14697446.jpg
# Moved back to train: gray_ratsnake_14702624.jpg
# Moved back to train: gray_ratsnake_14717182.jpg
# Moved back to train: gray_ratsnake_14724355.jpg
# Moved back to train: gray_ratsnake_14730674.jpg
# Moved back to train: gray_ratsnake_14734507.jpg
# Moved back to train: gray_ratsnake_14757410.jpg
# Moved back to train: gray_ratsnake_14784357.jpg
# Moved back to train: gray_ratsnake_14810276.jpg
# Moved back to train: gray_ratsnake_14854095.jpg
# Moved back to train: gray_ratsnake_14888250.jpg
# Moved back to train: gray_ratsnake_14892783.jpg
# Moved back to train: gray_ratsnake_14929774.jpg
# Moved back to train: gray_ratsnake_14953385.jpg
# Moved back to train: gray_ratsnake_14955673.jpg
# Moved back to train: gray_ratsnake_14970325.jpg
# Moved back to train: gray_ratsnake_15015693.jpg
# Moved back to train: gray_ratsnake_15044634.jpg
# Moved back to train: gray_ratsnake_15048951.jpg
# Moved back to train: gray_ratsnake_15049917.jpg
# Moved back to train: gray_ratsnake_15061878.jpg
# Moved back to train: historia_146.jpg
# Moved back to train: historia_290.jpg
# Moved back to train: historia_326.jpg
# Moved back to train: historia_355.jpg
# Moved back to train: historia_487.jpg
# Moved back to train: historia_547.jpg
# Moved back to train: historia_584.jpg
# Moved back to train: historia_619.jpg
# Moved back to train: honey_006.jpg
# Moved back to train: honey_010.jpg
# Moved back to train: honey_01_179.jpg
# Moved back to train: honey_01_401.jpg
# Moved back to train: honey_026.jpg
# Moved back to train: honey_067.jpg
# Moved back to train: honey_07_548.jpg
# Moved back to train: honey_07_625.jpg
# Moved back to train: honey_07_631.jpg
# Moved back to train: honey_080.jpg
# Moved back to train: honey_08_410.jpg
# Moved back to train: honey_095.jpg
# Moved back to train: honey_111.jpg
# Moved back to train: honey_117.jpg
# Moved back to train: honey_121.jpg
# Moved back to train: honey_128.jpg
# Moved back to train: honey_190.jpg
# Moved back to train: honey_2021_05_483.jpg
# Moved back to train: honey_2021_06_291.jpg
# Moved back to train: honey_2021_06_431.jpg
# Moved back to train: honey_2022_01_667.jpg
# Moved back to train: honey_221.jpg
# Moved back to train: honey_239.jpg
# Moved back to train: honey_244.jpg
# Moved back to train: honey_258.jpg
# Moved back to train: honey_306.jpg
# Moved back to train: honey_317.jpg
# Moved back to train: honey_333.jpg
# Moved back to train: honey_343.jpg
# Moved back to train: honey_415.jpg
# Moved back to train: honey_628.jpg
# Moved back to train: honey_709.jpg
# Moved back to train: honey_a_163.jpg
# Moved back to train: jetta_004.jpg
# Moved back to train: jetta_025.jpg
# Moved back to train: jetta_269.jpg
# Moved back to train: jetta_352.jpg
# Moved back to train: kiyoko_02_379.jpg
# Moved back to train: kiyoko_037.jpg
# Moved back to train: kiyoko_085.jpg
# Moved back to train: kiyoko_105.jpg
# Moved back to train: kiyoko_212.jpg
# Moved back to train: kiyoko_374.jpg
# Moved back to train: kiyoko_440.jpg
# Moved back to train: lena_065.jpg
# Moved back to train: lena_147.jpg
# Moved back to train: lena_159.jpg
# Moved back to train: lena_301.jpg
# Moved back to train: lena_501.jpg
# Moved back to train: lena_607.jpg
# Moved back to train: levi_005.jpg
# Moved back to train: levi_063.jpg
# Moved back to train: levi_278.jpg
# Moved back to train: levi_316.jpg
# Moved back to train: levi_389.jpg
# Moved back to train: levi_629.jpg
# Moved back to train: levi_688.jpg
# Moved back to train: master_chief_227.jpg
# Moved back to train: master_chief_310.jpg
# Moved back to train: master_chief_359.jpg
# Moved back to train: northby__071.jpg
# Moved back to train: northby__219.jpg
# Moved back to train: northby__238.jpg
# Moved back to train: orecchiette_203.jpg
# Moved back to train: orecchiette_304.jpg
# Moved back to train: orecchiette_362.jpg
# Moved back to train: orecchiette_439.jpg
# Moved back to train: orecchiette_571.jpg
# Moved back to train: pieck_150.jpg
# Moved back to train: pieck_156.jpg
# Moved back to train: pieck_270.jpg
# Moved back to train: pieck_422.jpg
# Moved back to train: pieck_437.jpg
# Moved back to train: pieck_445.jpg
# Moved back to train: pieck_466.jpg
# Moved back to train: pieck_474.jpg
# Moved back to train: pieck_508.jpg
# Moved back to train: pieck_513.jpg
# Moved back to train: pieck_527.jpg
# Moved back to train: pieck_653.jpg
# Moved back to train: pieck_660.jpg
# Moved back to train: pieck_697.jpg
# Moved back to train: pieck_706.jpg
# Moved back to train: pinkman_047.jpg
# Moved back to train: pinkman_082.jpg
# Moved back to train: pinkman_264.jpg
# Moved back to train: pinkman_268.jpg
# Moved back to train: pinkman_286.jpg
# Moved back to train: pinkman_524.jpg
# Moved back to train: pinkman_565.jpg
# Moved back to train: pinkman_637.jpg
# Moved back to train: queenie_102.jpg
# Moved back to train: queenie_2021_01_477.jpg
# Moved back to train: queenie_2021_01_539.jpg
# Moved back to train: queenie_2021_01_618.jpg
# Moved back to train: queenie_2021_03_721.jpg
# Moved back to train: queenie_2021_06_003.jpg
# Moved back to train: queenie_2021_06_168.jpg
# Moved back to train: queenie_2021_06_173.jpg
# Moved back to train: queenie_2021_06_288.jpg
# Moved back to train: queenie_2021_06_363.jpg
# Moved back to train: queenie_2021_06_535.jpg
# Moved back to train: queenie_2021_06_657.jpg
# Moved back to train: queenie_2021_07_643.jpg
# Moved back to train: queenie_2021_08_701.jpg
# Moved back to train: queenie_2021_09_017.jpg
# Moved back to train: queenie_2021_09_036.jpg
# Moved back to train: queenie_2021_09_081.jpg
# Moved back to train: queenie_2021_09_141.jpg
# Moved back to train: queenie_2021_09_229.jpg
# Moved back to train: queenie_2021_09_330.jpg
# Moved back to train: queenie_2021_09_397.jpg
# Moved back to train: queenie_2021_09_411.jpg
# Moved back to train: queenie_2021_09_696.jpg
# Moved back to train: queenie_2021_10_534.jpg
# Moved back to train: queenie_2021_11_537.jpg
# Moved back to train: queenie_2021_11_567.jpg
# Moved back to train: queenie_2021_14_579.jpg
# Moved back to train: queenie_2021_15_388.jpg
# Moved back to train: queenie_2021_15_512.jpg
# Moved back to train: queenie_2021_17_509.jpg
# Moved back to train: queenie_2021_17_700.jpg
# Moved back to train: queenie_260.jpg
# Moved back to train: queenie_321.jpg
# Moved back to train: queenie_347.jpg
# Moved back to train: queenie_425.jpg
# Moved back to train: queenie_484.jpg
# Moved back to train: queenie_492.jpg
# Moved back to train: queenie_532.jpg
# Moved back to train: queenie_536.jpg
# Moved back to train: queenie_555.jpg
# Moved back to train: queenie_621.jpg
# Moved back to train: sansa_002.jpg
# Moved back to train: sansa_042.jpg
# Moved back to train: sansa_048.jpg
# Moved back to train: sansa_055.jpg
# Moved back to train: sansa_077.jpg
# Moved back to train: sansa_090.jpg
# Moved back to train: sansa_115.jpg
# Moved back to train: sansa_123.jpg
# Moved back to train: sansa_129.jpg
# Moved back to train: sansa_144.jpg
# Moved back to train: sansa_157.jpg
# Moved back to train: sansa_165.jpg
# Moved back to train: sansa_194.jpg
# Moved back to train: sansa_198.jpg
# Moved back to train: sansa_199.jpg
# Moved back to train: sansa_2021_01_633.jpg
# Moved back to train: sansa_2021_04_523.jpg
# Moved back to train: sansa_2021_05_634.jpg
# Moved back to train: sansa_2021_08_659.jpg
# Moved back to train: sansa_2021_09_711.jpg
# Moved back to train: sansa_2021_10_395.jpg
# Moved back to train: sansa_2021_10_595.jpg
# Moved back to train: sansa_2021_10_615.jpg
# Moved back to train: sansa_2021_12_398.jpg
# Moved back to train: sansa_2021_12_506.jpg
# Moved back to train: sansa_2021_12_672.jpg
# Moved back to train: sansa_2021_13_365.jpg
# Moved back to train: sansa_2021_13_622.jpg
# Moved back to train: sansa_2021_14_530.jpg
# Moved back to train: sansa_2021_14_558.jpg
# Moved back to train: sansa_2021_14_572.jpg
# Moved back to train: sansa_2021_16_386.jpg
# Moved back to train: sansa_2021_17_429.jpg
# Moved back to train: sansa_2022_02_608.jpg
# Moved back to train: sansa_208.jpg
# Moved back to train: sansa_228.jpg
# Moved back to train: sansa_236.jpg
# Moved back to train: sansa_237.jpg
# Moved back to train: sansa_282.jpg
# Moved back to train: sansa_287.jpg
# Moved back to train: sansa_307.jpg
# Moved back to train: sansa_308.jpg
# Moved back to train: sansa_325.jpg
# Moved back to train: sansa_337.jpg
# Moved back to train: sansa_348.jpg
# Moved back to train: sansa_354.jpg
# Moved back to train: smoke_079.jpg
# Moved back to train: smoke_222.jpg
# Moved back to train: smoke_265.jpg
# Moved back to train: smoke_666.jpg
# Moved back to train: suzanne_058.jpg
# Moved back to train: suzanne_174.jpg
# Moved back to train: suzanne_178.jpg
# Moved back to train: suzanne_197.jpg
# Moved back to train: suzanne_209.jpg
# Moved back to train: suzanne_351.jpg
# Moved back to train: suzanne_372.jpg
# Moved back to train: suzanne_538.jpg
# Moved back to train: suzanne_540.jpg
# Moved back to train: suzanne_562.jpg
# Moved back to train: suzanne_646.jpg
# Moved back to train: suzanne_656.jpg
# Moved back to train: troi_108.jpg
# Moved back to train: troi_114.jpg
# Moved back to train: troi_263.jpg
# Moved back to train: troi_378.jpg
# Moved back to train: troi_383.jpg
# Moved back to train: troi_473.jpg
# Moved back to train: troi_490.jpg
# Moved back to train: troi_602.jpg
# Moved back to train: troi_714.jpg
# Moved back to train: unk_neo_2021_01_(11)_022.jpg
# Moved back to train: unk_neo_2021_01_(11)_066.jpg
# Moved back to train: unk_neo_2021_01_(11)_093.jpg
# Moved back to train: unk_neo_2021_01_(11)_118.jpg
# Moved back to train: unk_neo_2021_01_(11)_172.jpg
# Moved back to train: unk_neo_2021_01_(11)_242.jpg
# Moved back to train: unk_neo_2021_01_(11)_297.jpg
# Moved back to train: unk_neo_2021_01_(11)_449.jpg
# Moved back to train: unk_neo_2021_01_(11)_479.jpg
# Moved back to train: unk_neo_2021_01_(11)_616.jpg
# Moved back to train: unk_neo_2021_01_(11)_708.jpg
# Moved back to train: unk_neo_2021_03_(3)_294.jpg
# Moved back to train: unk_neo_2021_03_(3)_313.jpg
# Moved back to train: unk_neo_2021_03_(3)_322.jpg
# Moved back to train: unk_neo_2021_04_(3)_430.jpg
# Moved back to train: unk_neo_2021_04_(3)_515.jpg
# Moved back to train: unk_neo_2021_05_024.jpg
# Moved back to train: unk_neo_2021_05_031.jpg
# Moved back to train: unk_neo_2021_05_293.jpg
# Moved back to train: unk_neo_2021_07_(2)_703.jpg
# Moved back to train: wisp_176.jpg
# Moved back to train: wisp_318.jpg
# Moved back to train: wisp_335.jpg
# Total files moved back to train: 686
# Files in train folder: 686
# Files in kgot_aug folder: 43446

# %%
# import os
# import shutil
# import pandas as pd

# # Define paths
# csv_file = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\data_class_imbalance.csv"
# train_folder = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train"
# train_old_folder = r"D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train_old"

# # Read the CSV file
# df = pd.read_csv(csv_file)

# # Filter the DataFrame to include only rows where subset is "train"
# df_train = df[df['subset'] == 'train']

# # Get the list of image files in the CSV for the train subset
# csv_files = set(df_train['image_path'])

# # Get the list of files in the train folder
# train_files = set(os.listdir(train_folder))

# # Find files in CSV but missing from train folder
# missing_in_train = csv_files - train_files

# # Counter for moved files
# moved_files_count = 0

# # Move missing files from train_old to train
# for file in missing_in_train:
#     source_path = os.path.join(train_old_folder, file)
#     dest_path = os.path.join(train_folder, file)
#     if os.path.exists(source_path):
#         shutil.move(source_path, dest_path)
#         print(f"Moved: {file}")
#         moved_files_count += 1
#     else:
#         print(f"File not found in train_old: {file}")

# # Get updated list of files in the train folder
# updated_train_files = set(os.listdir(train_folder))

# # Find files still missing after the move
# still_missing = csv_files - updated_train_files

# # Print results
# print(f"\nTotal files moved from train_old to train: {moved_files_count}")
# print(f"Files still missing after move: {len(still_missing)}")

# if still_missing:
#     print("\nFiles still missing:")
#     for file in still_missing:
#         print(file)

# print(f"\nTotal files in CSV (train subset): {len(csv_files)}")
# print(f"Total files in train folder after move: {len(updated_train_files)}")

# # Find files in train folder but not in CSV
# extra_in_train = updated_train_files - csv_files
# if extra_in_train:
#     print(f"\nFiles in train folder but not in CSV: {len(extra_in_train)}")
#     for file in extra_in_train:
#         print(file)
# Out:
# Moved: queenie_2021_06_288_warped_ref_image4.jpg
# Moved: cup_125_warped_ref_image4.jpg
# Moved: anju_285_warped_ref_image4.jpg
# Moved: gilly_2020_05_341_warped_ref_image4.jpg
# Moved: ariel_01_(40)_300_warped_ref_image4.jpg
# Moved: unk_neo_2021_01_(11)_118_warped_ref_image4.jpg
# Moved: cavatappi_206_warped_ref_image4.jpg
# Moved: cup_213_warped_ref_image4.jpg
# Moved: sansa_002_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_035_warped_ref_image4.jpg
# Moved: cavatappi_064_warped_ref_image4.jpg
# Moved: cup_069_warped_ref_image4.jpg
# Moved: kiyoko_105_warped_ref_image4.jpg
# Moved: anju_013_warped_ref_image4.jpg
# Moved: levi_005_warped_ref_image4.jpg
# Moved: unk_neo_2021_05_031_warped_ref_image4.jpg
# Moved: pinkman_264_warped_ref_image4.jpg
# Moved: pieck_270_warped_ref_image4.jpg
# Moved: cavatappi_284_warped_ref_image4.jpg
# Moved: brock_(26)_289_warped_ref_image4.jpg
# Moved: belle_061_warped_ref_image4.jpg
# Moved: ariel_01_(40)_255_warped_ref_image4.jpg
# Moved: anju_224_warped_ref_image4.jpg
# Moved: brock_2021_07_188_warped_ref_image4.jpg
# Moved: anju_249_warped_ref_image2.jpg
# Moved: gilly_2020_08_246_warped_ref_image4.jpg
# Moved: ariel_01_(40)_136_warped_ref_image4.jpg
# Moved: sansa_236_warped_ref_image4.jpg
# Moved: cavatappi_113_warped_ref_image2.jpg
# Moved: armin_(14)_040_warped_ref_image2.jpg
# Moved: cavatappi_104_warped_ref_image4.jpg
# Moved: brock_(26)_132_warped_ref_image4.jpg
# Moved: orecchiette_304_warped_ref_image4.jpg
# Moved: cavatappi_145_warped_ref_image4.jpg
# Moved: gilly_2020_07_171_warped_ref_image4.jpg
# Moved: wisp_176_warped_ref_image4.jpg
# Moved: honey_121_warped_ref_image4.jpg
# Moved: lena_159_warped_ref_image4.jpg
# Moved: queenie_2021_09_330_warped_ref_image4.jpg
# Moved: dumbbell_148_warped_ref_image4.jpg
# Moved: jetta_025_warped_ref_image4.jpg
# Moved: honey_258_warped_ref_image4.jpg
# Moved: sansa_199_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_191_warped_ref_image4.jpg
# Moved: brock_07_101_warped_ref_image4.jpg
# Moved: sansa_337_warped_ref_image4.jpg
# Moved: brock_(26)_041_warped_ref_image4.jpg
# Moved: honey_010_warped_ref_image4.jpg
# Moved: eren_jaeger_230_warped_ref_image4.jpg
# Moved: cavatappi_207_warped_ref_image2.jpg
# Moved: 2022_neonate_dump_162_warped_ref_image2.jpg
# Moved: dumbbell_274_warped_ref_image4.jpg
# Moved: armin_(14)_253_warped_ref_image4.jpg
# Moved: sansa_055_warped_ref_image4.jpg
# Moved: cavatappi_207_warped_ref_image4.jpg
# Moved: sansa_237_warped_ref_image4.jpg
# Moved: ariel_01_(40)_225_warped_ref_image4.jpg
# Moved: troi_263_warped_ref_image4.jpg
# Moved: cavatappi_170_warped_ref_image4.jpg
# Moved: sansa_123_warped_ref_image4.jpg
# Moved: unk_neo_2021_01_(11)_172_warped_ref_image4.jpg
# Moved: sansa_348_warped_ref_image4.jpg
# Moved: master_chief_310_warped_ref_image4.jpg
# Moved: pinkman_082_warped_ref_image4.jpg
# Moved: anju_181_warped_ref_image4.jpg
# Moved: armin_(14)_311_warped_ref_image4.jpg
# Moved: dumbbell_205_warped_ref_image4.jpg
# Moved: armin_(14)_252_warped_ref_image4.jpg
# Moved: dumbbell_360_warped_ref_image4.jpg
# Moved: sansa_308_warped_ref_image4.jpg
# Moved: sansa_228_warped_ref_image2.jpg
# Moved: sansa_115_warped_ref_image4.jpg
# Moved: honey_006_warped_ref_image4.jpg
# Moved: sansa_048_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_162_warped_ref_image4.jpg
# Moved: suzanne_197_warped_ref_image4.jpg
# Moved: honey_095_warped_ref_image4.jpg
# Moved: smoke_079_warped_ref_image4.jpg
# Moved: gilly_2020_02_007_warped_ref_image4.jpg
# Moved: unk_neo_2021_03_(3)_294_warped_ref_image4.jpg
# Moved: armin_(14)_107_warped_ref_image4.jpg
# Moved: dumbbell_254_warped_ref_image4.jpg
# Moved: honey_239_warped_ref_image4.jpg
# Moved: brock_(26)_078_warped_ref_image4.jpg
# Moved: sansa_194_warped_ref_image4.jpg
# Moved: cavatappi_113_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_180_warped_ref_image4.jpg
# Moved: anju_271_warped_ref_image4.jpg
# Moved: honey_067_warped_ref_image4.jpg
# Moved: suzanne_058_warped_ref_image4.jpg
# Moved: jetta_352_warped_ref_image4.jpg
# Moved: anju_154_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_251_warped_ref_image4.jpg
# Moved: armin_(14)_279_warped_ref_image4.jpg
# Moved: honey_080_warped_ref_image4.jpg
# Moved: gilly_2020_07_044_warped_ref_image4.jpg
# Moved: honey_111_warped_ref_image4.jpg
# Moved: anju_072_warped_ref_image4.jpg
# Moved: sansa_077_warped_ref_image4.jpg
# Moved: gilly_2020_05_350_warped_ref_image4.jpg
# Moved: belle_183_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_030_warped_ref_image4.jpg
# Moved: honey_026_warped_ref_image4.jpg
# Moved: anju_249_warped_ref_image4.jpg
# Moved: brock_(26)_334_warped_ref_image4.jpg
# Moved: sansa_228_warped_ref_image4.jpg
# Moved: lena_065_warped_ref_image4.jpg
# Moved: gilly_2020_05_049_warped_ref_image4.jpg
# Moved: gilly_2020_08_046_warped_ref_image4.jpg
# Moved: cavatappi_119_warped_ref_image4.jpg
# Moved: anju_072_warped_ref_image2.jpg
# Moved: anju_257_warped_ref_image4.jpg
# Moved: gilly_2020_05_341_warped_ref_image2.jpg
# Moved: queenie_347_warped_ref_image2.jpg
# Moved: historia_326_warped_ref_image4.jpg
# Moved: unk_neo_2021_01_(11)_066_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_192_warped_ref_image4.jpg
# Moved: cavatappi_023_warped_ref_image4.jpg
# Moved: cup_309_warped_ref_image4.jpg
# Moved: suzanne_174_warped_ref_image4.jpg
# Moved: unk_neo_2021_01_(11)_297_warped_ref_image4.jpg
# Moved: gilly_2020_08_120_warped_ref_image4.jpg
# Moved: armin_(14)_040_warped_ref_image4.jpg
# Moved: suzanne_351_warped_ref_image4.jpg
# Moved: queenie_347_warped_ref_image4.jpg
# Moved: kiyoko_037_warped_ref_image4.jpg
# Moved: queenie_2021_06_168_warped_ref_image4.jpg
# Moved: gilly_2020_08_216_warped_ref_image4.jpg
# Moved: sansa_129_warped_ref_image4.jpg
# Moved: 2022_neonate_dump_034_warped_ref_image4.jpg
# Moved: anju_169_warped_ref_image4.jpg
# Moved: levi_063_warped_ref_image4.jpg
# Moved: dumbbell_098_warped_ref_image4.jpg
# Moved: brock_07_052_warped_ref_image4.jpg
# Moved: sansa_282_warped_ref_image4.jpg
# Moved: cup_070_warped_ref_image4.jpg
# Moved: queenie_2021_09_141_warped_ref_image4.jpg
# Moved: belle_183_warped_ref_image2.jpg
# Moved: queenie_2021_09_036_warped_ref_image4.jpg
# Moved: pinkman_047_warped_ref_image4.jpg
# Moved: gilly_2020_05_341_warped_id2.jpg
# Moved: anju_314_warped_ref_image4.jpg
# Moved: anju_045_warped_ref_image4.jpg
# Moved: gilly_2020_07_142_warped_ref_image4.jpg
# Moved: queenie_2021_09_081_warped_ref_image4.jpg
# Moved: unk_neo_2021_01_(11)_022_warped_ref_image4.jpg
# Moved: sansa_048_warped_ref_image2.jpg
# Moved: cavatappi_215_warped_ref_image4.jpg
# Moved: northby__071_warped_ref_image4.jpg
# Moved: anju_257_warped_ref_image2.jpg
# Moved: armin_(14)_038_warped_ref_image4.jpg
# Moved: anju_100_warped_ref_image4.jpg
# Moved: anju_259_warped_ref_image4.jpg
# Moved: brock_(26)_289_warped_ref_image2.jpg
# Moved: belle_223_warped_ref_image4.jpg
# Moved: gilly_2020_08_331_warped_ref_image4.jpg
# Moved: sansa_090_warped_ref_image4.jpg
# Moved: unk_neo_2021_03_(3)_294_warped_ref_image2.jpg
# Moved: cup_329_warped_ref_image4.jpg
#
# Total files moved from train_old to train: 159
# Files still missing after move: 0
#
# Total files in CSV (train subset): 43605
# Total files in train folder after move: 43605

# %% [markdown]
# ## Methodology visualize

# %%
# import matplotlib.pyplot as plt
# import cv2
# import numpy as np

# def visualize_warped_curve_properties(warped_image, reference_curve, avg_width, scale_factor=None, num_sample_points=15):
#     # Create a white background of the same size as the warped image
#     h, w = warped_image.shape[:2]
#     white_background = np.ones((h, w, 3), dtype=np.uint8) * 255
    
#     # Create a mask for non-transparent pixels
#     mask = warped_image[:, :, 3] > 0
    
#     # Paste the BGR channels of the warped image onto the white background
#     white_background[mask] = warped_image[mask, :3]
    
#     # Adjust reference curve to match warped image coordinates
#     min_x, min_y = np.min(reference_curve, axis=0)
#     padding = avg_width
#     adjusted_curve = reference_curve - [min_x, min_y] + [padding, padding]

#     # Sample points along the curve
#     sample_indices = np.linspace(0, len(adjusted_curve) - 1, num_sample_points, dtype=int)
#     sampled_points = adjusted_curve[sample_indices]

#     # Calculate tangents and normals
#     tangents = np.zeros_like(sampled_points)
#     normals = np.zeros_like(sampled_points)

#     for i in range(len(sampled_points)):
#         if i == 0:
#             tangent = sampled_points[1] - sampled_points[0]
#         elif i == len(sampled_points) - 1:
#             tangent = sampled_points[-1] - sampled_points[-2]
#         else:
#             tangent = sampled_points[i+1] - sampled_points[i-1]
        
#         tangent = tangent / np.linalg.norm(tangent)
#         normal = np.array([-tangent[1], tangent[0]])
        
#         tangents[i] = tangent
#         normals[i] = normal

#     # Create the plot with white background
#     fig, ax = plt.subplots(figsize=(12, 12), facecolor='white')
    
#     # Display the image (already in BGR format)
#     ax.imshow(white_background)

#     # Plot the curve as a blue line
#     ax.plot(adjusted_curve[:, 0], adjusted_curve[:, 1], color='blue', linewidth=2, zorder=2, label='Curve')

#     # Plot keypoints and add numbers
#     ax.scatter(sampled_points[:, 0], sampled_points[:, 1], color='lime', s=50, zorder=3, label='Keypoints')
#     for i, (x, y) in enumerate(sampled_points, start=1):
#         ax.text(x + 5, y + 5, str(i), color='white', fontsize=18, fontweight='bold', 
#                 ha='left', va='bottom', bbox=dict(facecolor='black', alpha=0.7, edgecolor='none', pad=0))

#     # Plot tangent vectors
#     tangent_scale = 30
#     ax.quiver(sampled_points[:, 0], sampled_points[:, 1], 
#               tangents[:, 0], tangents[:, 1], 
#               color='red', scale=1/tangent_scale, scale_units='xy', 
#               angles='xy', width=0.004, zorder=4, label='Tangent Vectors')

#     # Plot normal vectors in yellow
#     normal_scale = 30
#     ax.quiver(sampled_points[:, 0], sampled_points[:, 1], 
#               normals[:, 0], normals[:, 1], 
#               color='yellow', scale=1/normal_scale, scale_units='xy', 
#               angles='xy', width=0.004, zorder=4, label='Normal Vectors')

#     # Set labels and title with specified font sizes
#     ax.set_title('Warped Image with Curve Properties', fontsize=24)

#     # Add legend with larger font size
#     ax.legend(loc='upper right', fontsize=18)

#     # Add grid
#     ax.grid(True, linestyle='--', color='gray', alpha=0.5)

#     # Set x and y ticks
#     x_ticks = np.arange(0, w, 100)
#     y_ticks = np.arange(0, h, 100)
#     ax.set_xticks(x_ticks)
#     ax.set_yticks(y_ticks)
#     ax.set_xticklabels(x_ticks, fontsize=12)
#     ax.set_yticklabels(y_ticks, fontsize=12)

#     # Set the plot limits to match the image size
#     ax.set_xlim(0, w)
#     ax.set_ylim(h, 0)  # Reverse Y-axis to match image coordinates

#     # Adjust layout and display
#     plt.tight_layout()
#     return fig

# %%
# def warp_straightened_image(straightened, reference_curve, avg_width, scale_factor=None):
#     height, width = straightened.shape[:2]
    
#     extended_curve = interpolate_centerline(reference_curve, int(len(reference_curve) * 1.2))
    
#     min_x, min_y = np.min(extended_curve, axis=0)
#     max_x, max_y = np.max(extended_curve, axis=0)
    
#     padding = avg_width
#     output_width = int(max_x - min_x + 2 * padding)
#     output_height = int(max_y - min_y + 2 * padding)
    
#     warped = np.zeros((output_height, output_width, 4), dtype=np.uint8)
#     weight = np.zeros((output_height, output_width), dtype=np.float32)
    
#     _, normals = calculate_tangents_and_normals(extended_curve)
    
#     straightened = ensure_rgba(straightened)
    
#     y_coords, x_coords = np.mgrid[0:height, 0:width]
#     t = x_coords / width
#     curve_indices = np.minimum((t * (len(extended_curve) - 1)).astype(int), len(extended_curve) - 1)
    
#     curve_points = extended_curve[curve_indices]
#     normal_vectors = normals[curve_indices]
    
#     offsets = (y_coords / height - 0.5) * avg_width
    
#     warped_coords = curve_points - [min_x, min_y] + [padding, padding] + offsets[:, :, np.newaxis] * normal_vectors
#     warped_coords = warped_coords.astype(int)
    
#     valid_mask = (warped_coords[:, :, 0] >= 0) & (warped_coords[:, :, 0] < output_width) & \
#                  (warped_coords[:, :, 1] >= 0) & (warped_coords[:, :, 1] < output_height)
    
#     warped[warped_coords[valid_mask, 1], warped_coords[valid_mask, 0]] = straightened[y_coords[valid_mask], x_coords[valid_mask]]
#     weight[warped_coords[valid_mask, 1], warped_coords[valid_mask, 0]] += 1

#     mask = (warped[:,:,3] > 0).astype(np.uint8) * 255

#     kernel_close = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
#     closed_mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel_close)

#     contours, _ = cv2.findContours(closed_mask, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

#     fill_mask = np.zeros_like(mask)
#     cv2.drawContours(fill_mask, contours, -1, 255, -1)
    
#     transparent_mask = (fill_mask == 255) & (warped[:,:,3] == 0)

#     warped_filled = warped.copy()
#     for i in range(3):
#         warped_filled[:,:,i] = cv2.inpaint(warped[:,:,i], transparent_mask.astype(np.uint8), 3, cv2.INPAINT_TELEA)
    
#     warped_filled[:,:,3] = np.where(transparent_mask, 255, warped[:,:,3])

#     # After warping is complete, visualize the curve properties
#     fig = visualize_warped_curve_properties(warped_filled, extended_curve, avg_width, scale_factor)

#     return warped, warped_filled, warped, fig

# %%
# import numpy as np
# import cv2
# import json
# import os
# import pycocotools.mask as mask_utils
# import matplotlib.pyplot as plt


# def circulate_image_from_coco(json_file_path, image_folder, output_folder, output_width=1024, output_height=1024, scale=True):
#     with open(json_file_path, 'r') as f:
#         coco_data = json.load(f)

#     os.makedirs(output_folder, exist_ok=True)

#     image_ids = set(ann['image_id'] for ann in coco_data['annotations'])

#     frame_images = []

#     for ref_image_id in image_ids:
#         ref_ann = next((ann for ann in coco_data['annotations'] if ann['image_id'] == ref_image_id), None)
#         if ref_ann is None:
#             print(f"No annotation found for reference image ID {ref_image_id}")
#             continue

#         reference_keypoints = np.array(ref_ann['keypoints']).reshape(-1, 3)[:, :2]

#         for ann in coco_data['annotations']:
#             image_id = ann['image_id']
#             image_info = next((img for img in coco_data['images'] if img['id'] == image_id), None)
#             if image_info is None:
#                 print(f"No image info found for image ID {image_id}")
#                 continue

#             image_filename = image_info['file_name']
#             image_path = os.path.join(image_folder, image_filename)

#             if not os.path.exists(image_path):
#                 print(f"Image not found: {image_path}")
#                 continue

#             try:
#                 image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
#                 if image is None:
#                     print(f"Failed to read image: {image_path}")
#                     continue
                
#                 image = ensure_rgba(image)

#                 keypoints = np.array(ann['keypoints']).reshape(-1, 3)[:, :2]

#                 rle = ann['segmentation']
#                 mask = mask_utils.decode(rle)

#                 _, widths = divide_mask_by_centerline(mask, keypoints)
#                 avg_width = int(np.mean(widths))

#                 total_length = np.sum(np.sqrt(np.sum(np.diff(keypoints, axis=0)**2, axis=1)))
                
#                 straightened = straighten_image(image, keypoints, mask, total_length, avg_width)
#                 print(f"Straightened image width: {straightened.shape[1]}")

#                 if scale:
#                     reference_curve, scale_factor = generate_reference_curve(reference_keypoints, num_points=10000, target_length=straightened.shape[1])
#                 else:
#                     reference_curve, scale_factor = generate_reference_curve(reference_keypoints, num_points=10000)

#                 warped, warped_filled, edge, fig = warp_straightened_image(straightened, reference_curve, avg_width, scale_factor)
                
#                 # Save the matplotlib figure
#                 fig_filename = f"{os.path.splitext(image_filename)[0]}_warped_ref_image{ref_image_id}_curve_properties.png"
#                 fig_path = os.path.join(output_folder, fig_filename)
#                 fig.savefig(fig_path, dpi=300, bbox_inches='tight', facecolor='white')
#                 plt.close(fig)

#             except Exception as e:
#                 print(f"Error processing image {image_filename}: {str(e)}")

#     return frame_images

# %%
# image_folder = r'D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\train'
# output_folder = r'D:\Personal_Project\snake_straightening\data\classification_dataset_aug_no_bg_kgot\kgot_aug'
# coco_json = r'D:\Personal_Project\snake_straightening\data\isIDD_v2\label\all_1024\all_annotations_1024.json'

# circulate_image_from_coco(coco_json, image_folder, output_folder, output_width=1024, output_height=1024, scale=True)
